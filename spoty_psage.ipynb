# %%
import pandas

# %%
import csv

# %%
import json

# %%
in_file = pandas.read_csv('spotify-2023.csv', encoding='ISO-8859-1')

# %%
file_path = 'spotify-2023.csv'
df = pandas.read_csv(file_path, encoding='ISO-8859-1')
filtered_df = df[df['released_year'] == 2022]

# %%
filtered_df
# Out:
#                         track_name                       artist(s)_name
# 14                       As It Was                         Harry Styles  \
# 15                       Kill Bill                                  SZA
# 26   Calm Down (with Selena Gomez)                  Rï¿½ï¿½ma, Selena G
# 32                        Creepin'  The Weeknd, 21 Savage, Metro Boomin
# 33                       Anti-Hero                         Taylor Swift
# ..                             ...                                  ...
# 948                   My Mind & Me                         Selena Gomez
# 949      Bigger Than The Whole Sky                         Taylor Swift
# 950           A Veces (feat. Feid)                   Feid, Paulo Londra
# 951                  En La De Ella                   Feid, Sech, Jhayco
# 952                          Alone                            Burna Boy
#
#      artist_count  released_year  released_month  released_day
# ...

# %%
file_path = 'spotify-2023.csv'
df = pandas.read_csv(file_path, encoding='ISO-8859-1')
filtered_by_2023 = df[df['released_year'] == 2023]

# %%
filtered_by_2023
# Out:
#                               track_name
# 0    Seven (feat. Latto) (Explicit Ver.)  \
# 1                                   LALA
# 2                                vampire
# 4                         WHERE SHE GOES
# 5                               Sprinter
# ..                                   ...
# 381         I'm Not Here To Make Friends
# 382                            TRUSTFALL
# 385            VIBE (feat. Jimin of BTS)
# 398                             Muï¿½ï¿½
# 404                      Sugar Rush Ride
#
#                              artist(s)_name  artist_count  released_year
# 0                          Latto, Jung Kook             2           2023  \
# 1                               Myke Towers             1           2023
# 2                            Olivia Rodrigo             1           2023
# 4                                 Bad Bunny             1           2023
# 5                         Dave, Central Cee             2           2023
# ...

# %%
file_path = 'spotify-2023.csv'
df = pandas.read_csv(file_path, encoding='ISO-8859-1')

# %%
for index, row in df.iterrows():
    if row['released_day'] < 24:
        print(row['released_day'])
# Out:
# 14
# 23
# 23
# 18
# 1
# 16
# 7
# 15
# 17
# 17
# 7
# 12
# 14
# 8
# 13
# 22
# 7
# 1
# 2
# 22
# 13
# 2
# 21
# 23
# 1
# 7
# 1
# 1
# 19
# 10
# 9
# 21
# 23
# 13
# 21
# 2
# 6
# 15
# 15
# 14
# 4
# 3
# 6
# 1
# 21
# 2
# 14
# 7
# 23
# 15
# 14
# 6
# 1
# 17
# 22
# 20
# 22
# 1
# 22
# 23
# 7
# 9
# 3
# 8
# 6
# 22
# 20
# 17
# 17
# 8
# 5
# 12
# 17
# 9
# 1
# 9
# 1
# 2
# 14
# 1
# 7
# 20
# 10
# 11
# 1
# 1
# 2
# 22
# 7
# 17
# 9
# 8
# 12
# 22
# 10
# 15
# 9
# 11
# 19
# 16
# 17
# 11
# 21
# 15
# 2
# 1
# 11
# 20
# 2
# 2
# 22
# 1
# 20
# 19
# 1
# 1
# 13
# 6
# 1
# 10
# 1
# 2
# 5
# 4
# 17
# 1
# 19
# 4
# 23
# 13
# 4
# 1
# 20
# 6
# 2
# 1
# 5
# 2
# 1
# 1
# 12
# 1
# 1
# 19
# 6
# 17
# 13
# 21
# 18
# 21
# 19
# 20
# 1
# 13
# 16
# 9
# 6
# 7
# 10
# 1
# 20
# 8
# 19
# 19
# 2
# 1
# 11
# 15
# 2
# 2
# 17
# 13
# 2
# 2
# 23
# 12
# 2
# 4
# 2
# 1
# 22
# 8
# 2
# 1
# 5
# 18
# 21
# 7
# 19
# 21
# 2
# 6
# 14
# 17
# 21
# 1
# 4
# 14
# 11
# 2
# 14
# 1
# 16
# 10
# 10
# 4
# 5
# 1
# 21
# 7
# 2
# 8
# 10
# 1
# 4
# 22
# 21
# 23
# 21
# 14
# 3
# ...

# %%
import pandas as pd
file_path = 'spotify-2023.csv'

df = pd.read_csv(file_path, encoding='ISO-8859-1')
for index, row in df.iterrows():
    if row['released_day'] < 24:
        print(f"Author: {row['artist(s)_name']},Track Name: {row['track_name']}, Released Day: {row['released_day']}")
# Out:
# Author: Latto, Jung Kook,Track Name: Seven (feat. Latto) (Explicit Ver.), Released Day: 14
# Author: Myke Towers,Track Name: LALA, Released Day: 23
# Author: Taylor Swift,Track Name: Cruel Summer, Released Day: 23
# Author: Bad Bunny,Track Name: WHERE SHE GOES, Released Day: 18
# Author: Dave, Central Cee,Track Name: Sprinter, Released Day: 1
# Author: Eslabon Armado, Peso Pluma,Track Name: Ella Baila Sola, Released Day: 16
# Author: Quevedo,Track Name: Columbia, Released Day: 7
# Author: Gunna,Track Name: fukumean, Released Day: 15
# Author: Peso Pluma, Yng Lvcas,Track Name: La Bebe - Remix, Released Day: 17
# Author: Bad Bunny, Grupo Frontera,Track Name: un x100to, Released Day: 17
# Author: NewJeans,Track Name: Super Shy, Released Day: 7
# Author: Miley Cyrus,Track Name: Flowers, Released Day: 12
# Author: David Kushner,Track Name: Daylight, Released Day: 14
# Author: SZA,Track Name: Kill Bill, Released Day: 8
# ...

# %%
filtered_df
# Out:
#                         track_name                       artist(s)_name
# 14                       As It Was                         Harry Styles  \
# 15                       Kill Bill                                  SZA
# 26   Calm Down (with Selena Gomez)                  Rï¿½ï¿½ma, Selena G
# 32                        Creepin'  The Weeknd, 21 Savage, Metro Boomin
# 33                       Anti-Hero                         Taylor Swift
# ..                             ...                                  ...
# 948                   My Mind & Me                         Selena Gomez
# 949      Bigger Than The Whole Sky                         Taylor Swift
# 950           A Veces (feat. Feid)                   Feid, Paulo Londra
# 951                  En La De Ella                   Feid, Sech, Jhayco
# 952                          Alone                            Burna Boy
#
#      artist_count  released_year  released_month  released_day
# ...
